# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("C:/Users/jumal/OneDrive/Desktop/Data Analyst/Project/EMPLOYEE_SALES_and_HR_ANALYSIS.csv")
df.head()
# Out:
#    employee_id     employee_name region   hire_date  monthly_salary  \
# 0            1  Jermaine Burgess  North  05-06-2016           94618
# 1            2        Sarah Lara  North  23-07-2015          113596
# 2            3     Peter Pearson   West  16-08-2017           54288
# 3            4  Crystal Martinez  South  13-01-2024          119947
# 4            5   Andrea Matthews  South  20-04-2023           75091
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 0         377245                   34                   2                 20
# 1         225054                   38                   4                  5
# 2         258447                   39                   5                 15
# 3         374710                   24                   5                  5
# 4         372136                   29                   3                  5
#
#    department_id department  annual_budget   head_of_department
# ...

# %%
df.tail()
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# 19995         276007                   41                   5
# 19996         190898                   19                   3
# 19997         269492                   31                   1
# 19998         138202                    2                   3
# 19999          28284                   45                   4
#
#        incentive_percent  department_id department  annual_budget  \
# 19995                 15              2        NaN            NaN
# ...

# %%
# Identify duplicate records in Rows
df.duplicated().sum()
# Out:
# 0

# %%
# Check Duplicate values in Columns
df["monthly_salary"].duplicated().sum()
# Out:
# 2055

# %%
df.drop_duplicates(["employee_id"])
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 4                5    Andrea Matthews  South  20-04-2023           75091
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
df.drop_duplicates()
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 4                5    Andrea Matthews  South  20-04-2023           75091
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
#Find shape of dataframe i.e number of rows and columns.
df.shape
# Out:
# (20000, 13)

# %%
# Lets check all columns present in dataframe
df.columns
# Out:
# Index(['employee_id', 'employee_name', 'region', 'hire_date', 'monthly_salary',
#        'monthly_sales', 'num_clients_handled', 'performance_rating',
#        'incentive_percent', 'department_id', 'department', 'annual_budget',
#        'head_of_department'],
#       dtype='object')

# %%
# Check dimension of dataframe
df.ndim
# Out:
# 2

# %%
# check type of dataset
df.dtypes
# Out:
# employee_id              int64
# employee_name           object
# region                  object
# hire_date               object
# monthly_salary           int64
# monthly_sales            int64
# num_clients_handled      int64
# performance_rating       int64
# incentive_percent        int64
# department_id            int64
# department              object
# annual_budget          float64
# head_of_department      object
# dtype: object

# %%
# display only Numaricals dataset
df.describe()
# Out:
#         employee_id  monthly_salary  monthly_sales  num_clients_handled  \
# count  20000.000000    20000.000000   20000.000000         20000.000000
# mean   10000.500000    74864.934200  255491.441100            25.073700
# std     5773.647028    26107.521371  141467.309865            14.069032
# min        1.000000    30002.000000   10019.000000             1.000000
# 25%     5000.750000    52052.750000  133957.000000            13.000000
# 50%    10000.500000    75115.000000  255621.500000            25.000000
# 75%    15000.250000    97558.250000  377582.250000            37.000000
# max    20000.000000   119999.000000  499978.000000            49.000000
#
#        performance_rating  incentive_percent  department_id  annual_budget
# count        20000.000000       20000.000000   20000.000000   6.000000e+00
# mean             2.992700          10.095250       3.499100   5.274340e+06
# std              1.422901           7.053876       1.710861   2.754506e+06
# ...

# %%
# Display summary 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   employee_id          20000 non-null  int64
#  1   employee_name        20000 non-null  object
#  2   region               20000 non-null  object
#  3   hire_date            20000 non-null  object
#  4   monthly_salary       20000 non-null  int64
#  5   monthly_sales        20000 non-null  int64
#  6   num_clients_handled  20000 non-null  int64
#  7   performance_rating   20000 non-null  int64
#  8   incentive_percent    20000 non-null  int64
#  9   department_id        20000 non-null  int64
#  10  department           6 non-null      object
#  11  annual_budget        6 non-null      float64
#  12  head_of_department   6 non-null      object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 2.0+ MB

# %%
#How do you find missing data in a DataFrame?

df.isnull().sum()
# Out:
# employee_id                0
# employee_name              0
# region                     0
# hire_date                  0
# monthly_salary             0
# monthly_sales              0
# num_clients_handled        0
# performance_rating         0
# incentive_percent          0
# department_id              0
# department             19994
# annual_budget          19994
# head_of_department     19994
# dtype: int64

# %%
# Check for columns having null values and count of null contaning rows."].isnull().sum()
df["annual_budget"].isnull().sum()
# Out:
# 19994

# %%
df.dropna(axis=0, inplace=False)
# Out:
#    employee_id      employee_name region   hire_date  monthly_salary  \
# 0            1   Jermaine Burgess  North  05-06-2016           94618
# 1            2         Sarah Lara  North  23-07-2015          113596
# 2            3      Peter Pearson   West  16-08-2017           54288
# 3            4   Crystal Martinez  South  13-01-2024          119947
# 4            5    Andrea Matthews  South  20-04-2023           75091
# 5            6  Michael Nicholson   West  02-11-2015          108872
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 0         377245                   34                   2                 20
# 1         225054                   38                   4                  5
# 2         258447                   39                   5                 15
# 3         374710                   24                   5                  5
# 4         372136                   29                   3                  5
# ...

# %%
df.dropna(axis=1, inplace=False)
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 4                5    Andrea Matthews  South  20-04-2023           75091
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
df.ffill(inplace=False)
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 4                5    Andrea Matthews  South  20-04-2023           75091
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
df.bfill()
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 4                5    Andrea Matthews  South  20-04-2023           75091
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
df["monthly_salary"].mean()
# Out:
# 74864.9342

# %%
df["monthly_salary"].mode()
# Out:
# 0     30207
# 1     30645
# 2     48083
# 3     51735
# 4     56025
# 5     62961
# 6    105450
# 7    115893
# 8    116190
# Name: monthly_salary, dtype: int64

# %%
df["monthly_salary"].median()
# Out:
# 75115.0

# %%
df["monthly_salary"].max()
# Out:
# 119999

# %%
df["monthly_salary"].min()
# Out:
# 30002

# %%
df.replace(np.NaN, 30002)
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 4                5    Andrea Matthews  South  20-04-2023           75091
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
df.head(3)
# Out:
#    employee_id     employee_name region   hire_date  monthly_salary  \
# 0            1  Jermaine Burgess  North  05-06-2016           94618
# 1            2        Sarah Lara  North  23-07-2015          113596
# 2            3     Peter Pearson   West  16-08-2017           54288
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 0         377245                   34                   2                 20
# 1         225054                   38                   4                  5
# 2         258447                   39                   5                 15
#
#    department_id department  annual_budget   head_of_department
# 0              4  Marketing      1520961.0     Kenneth Crawford
# 1              5      Sales      3718752.0  Katherine Flores MD
# 2              3         HR      4346682.0        Patrick Braun

# %%
df.drop([1,3,5,19995,19998,19999])
# Out:
#        employee_id         employee_name region   hire_date  monthly_salary  \
# 0                1      Jermaine Burgess  North  05-06-2016           94618
# 2                3         Peter Pearson   West  16-08-2017           54288
# 4                5       Andrea Matthews  South  20-04-2023           75091
# 6                7     Jessica Hernandez   West  05-04-2018           89216
# 7                8           Mary Morrow   West  12-04-2024          107162
# ...            ...                   ...    ...         ...             ...
# 19992        19993     Christopher Olson   West  16-11-2023           30622
# 19993        19994  Christopher Williams   East  21-10-2015           37245
# 19994        19995         Melissa White  South  30-03-2020          117579
# 19996        19997           Ellen Grant  North  28-09-2021           93532
# 19997        19998      Shane Hughes DVM   West  02-06-2017           94439
#
# ...

# %%
df.drop([3,5,9])
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 4                5    Andrea Matthews  South  20-04-2023           75091
# 6                7  Jessica Hernandez   West  05-04-2018           89216
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
df.drop(["monthly_salary", "num_clients_handled"], axis=1)
# Out:
#        employee_id      employee_name region   hire_date  monthly_sales  \
# 0                1   Jermaine Burgess  North  05-06-2016         377245
# 1                2         Sarah Lara  North  23-07-2015         225054
# 2                3      Peter Pearson   West  16-08-2017         258447
# 3                4   Crystal Martinez  South  13-01-2024         374710
# 4                5    Andrea Matthews  South  20-04-2023         372136
# ...            ...                ...    ...         ...            ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020         276007
# 19996        19997        Ellen Grant  North  28-09-2021         190898
# 19997        19998   Shane Hughes DVM   West  02-06-2017         269492
# 19998        19999     Lindsay Landry  North  12-10-2019         138202
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023          28284
#
#        performance_rating  incentive_percent  department_id department  \
# ...

# %%
df.drop(["employee_name", "region", "hire_date"], axis=1)
# Out:
#        employee_id  monthly_salary  monthly_sales  num_clients_handled  \
# 0                1           94618         377245                   34
# 1                2          113596         225054                   38
# 2                3           54288         258447                   39
# 3                4          119947         374710                   24
# 4                5           75091         372136                   29
# ...            ...             ...            ...                  ...
# 19995        19996          110831         276007                   41
# 19996        19997           93532         190898                   19
# 19997        19998           94439         269492                   31
# 19998        19999           68191         138202                    2
# 19999        20000           96951          28284                   45
#
#        performance_rating  incentive_percent  department_id department  \
# ...

# %%
df.drop([1,3,5,19997],axis=0)
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 2                3      Peter Pearson   West  16-08-2017           54288
# 4                5    Andrea Matthews  South  20-04-2023           75091
# 6                7  Jessica Hernandez   West  05-04-2018           89216
# 7                8        Mary Morrow   West  12-04-2024          107162
# ...            ...                ...    ...         ...             ...
# 19994        19995      Melissa White  South  30-03-2020          117579
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
df[["monthly_salary", "num_clients_handled"]].head(7)
# Out:
#    monthly_salary  num_clients_handled
# 0           94618                   34
# 1          113596                   38
# 2           54288                   39
# 3          119947                   24
# 4           75091                   29
# 5          108872                    4
# 6           89216                   41

# %%
vari=df[["monthly_salary", "num_clients_handled"]].head(20)
plt.scatter(vari["monthly_salary"], vari["num_clients_handled"], color="Red")
plt.xlabel("monthly_salary")
plt.ylabel("num_clients_handled")
plt.title("Monthly Salary vs Clients Handled for First 7 Employees")
plt.show()

# %%
df[50:53]
# Out:
#     employee_id     employee_name region   hire_date  monthly_salary  \
# 50           51  Aaron Washington   West  13-07-2017           61104
# 51           52     Carrie Bowers   West  12-03-2024           83586
# 52           53    Hayley Goodwin   West  10-11-2017           74420
#
#     monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 50          85489                    6                   4                  0
# 51         488031                   30                   3                 20
# 52          40767                    4                   5                 15
#
#     department_id department  annual_budget head_of_department
# 50              6        NaN            NaN                NaN
# 51              2        NaN            NaN                NaN
# 52              2        NaN            NaN                NaN

# %%
df.loc[50:53]
# Out:
#     employee_id     employee_name region   hire_date  monthly_salary  \
# 50           51  Aaron Washington   West  13-07-2017           61104
# 51           52     Carrie Bowers   West  12-03-2024           83586
# 52           53    Hayley Goodwin   West  10-11-2017           74420
# 53           54  Bethany Sullivan  South  19-11-2023           34061
#
#     monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 50          85489                    6                   4                  0
# 51         488031                   30                   3                 20
# 52          40767                    4                   5                 15
# 53         459781                   36                   5                  0
#
#     department_id department  annual_budget head_of_department
# 50              6        NaN            NaN                NaN
# 51              2        NaN            NaN                NaN
# ...

# %%
df.iloc[50:53]
# Out:
#     employee_id     employee_name region   hire_date  monthly_salary  \
# 50           51  Aaron Washington   West  13-07-2017           61104
# 51           52     Carrie Bowers   West  12-03-2024           83586
# 52           53    Hayley Goodwin   West  10-11-2017           74420
#
#     monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 50          85489                    6                   4                  0
# 51         488031                   30                   3                 20
# 52          40767                    4                   5                 15
#
#     department_id department  annual_budget head_of_department
# 50              6        NaN            NaN                NaN
# 51              2        NaN            NaN                NaN
# 52              2        NaN            NaN                NaN

# %%
df[["employee_id", "employee_name", "region"]].head()
# Out:
#    employee_id     employee_name region
# 0            1  Jermaine Burgess  North
# 1            2        Sarah Lara  North
# 2            3     Peter Pearson   West
# 3            4  Crystal Martinez  South
# 4            5   Andrea Matthews  South

# %%
vari=df[["num_clients_handled", "employee_name", "region"]].head(7)
sns.barplot(x="employee_name", y="num_clients_handled", data=vari, hue="region")
plt.show()

# %%
df.iloc[[25,50,55,2000,2020,2500,2600]]
# Out:
#       employee_id       employee_name region   hire_date  monthly_salary  \
# 25             26  Stephanie Johnston  North  03-04-2020           96874
# 50             51    Aaron Washington   West  13-07-2017           61104
# 55             56       Carl Campbell   West  11-08-2019           92055
# 2000         2001      Benjamin Hanna   East  15-05-2022           69497
# 2020         2021       Margaret Bush   West  24-06-2019          110909
# 2500         2501    Brandon Martinez  South  17-09-2020           60171
# 2600         2601      Andrea Bridges  North  15-02-2020           74693
#
#       monthly_sales  num_clients_handled  performance_rating  \
# 25           431669                   10                   1
# 50            85489                    6                   4
# 55            71110                   10                   5
# 2000          76843                   42                   2
# 2020         263064                   22                   2
# ...

# %%
df.loc[[25,50,55,2000,2020,2500,2600],["employee_id", "employee_name", "region"]]
# Out:
#       employee_id       employee_name region
# 25             26  Stephanie Johnston  North
# 50             51    Aaron Washington   West
# 55             56       Carl Campbell   West
# 2000         2001      Benjamin Hanna   East
# 2020         2021       Margaret Bush   West
# 2500         2501    Brandon Martinez  South
# 2600         2601      Andrea Bridges  North

# %%
df.iloc[[25,50,55,2000,2020,2100,2200],[0,1,2]]
# Out:
#       employee_id       employee_name region
# 25             26  Stephanie Johnston  North
# 50             51    Aaron Washington   West
# 55             56       Carl Campbell   West
# 2000         2001      Benjamin Hanna   East
# 2020         2021       Margaret Bush   West
# 2100         2101         Tonya Banks   West
# 2200         2201      Valerie Duarte  South

# %%
vari=df.loc[[1000,1500,2000,2500,2600,2700,3000], ["monthly_sales", "performance_rating"]]
plt.plot(vari["monthly_sales"], vari["performance_rating"])
plt.xlabel("performance_rating")
plt.ylabel("monthly_sales")
plt.show()

# %%
df.iloc[[4000,4100,4200,4300,4400,4500,4600,4700], [6, 5]]
# Out:
#       num_clients_handled  monthly_sales
# 4000                   18         382636
# 4100                   12         190900
# 4200                    7          33936
# 4300                    6         304036
# 4400                   10         483291
# 4500                    3         243814
# 4600                   13         214012
# 4700                   15         450292

# %%
vari=df.loc[[0,2,3],["region", "annual_budget"]]
plt.pie(vari["annual_budget"], labels=vari["region"], autopct="%0.0F%%")
plt.show()

# %%
vari=df.iloc[[0,1,2,3,4,5],[11,12]]
sns.boxplot(x="head_of_department", y="annual_budget", data=vari)
plt.show()

# %%
vari=df.loc[[0,1,2,3,4,5], ["department", "annual_budget"]]
plt.bar(vari["department"], vari["annual_budget"])
plt.xlabel("department")
plt.ylabel("annual_budget")
plt.title("Annual Budget by Department")
plt.show()

# %%
vari=df.iloc[[0,1,2,3,4,5],[5,10]]
plt.pie(vari["monthly_sales"], labels=vari["department"], autopct="%0.0F%%")
plt.show()

# %%
vari=df.loc[[15,16,17,18,19,100,101,102,103], ["num_clients_handled"]]
sns.displot(x="num_clients_handled", data=vari)
plt.show()

# %%
df["department"].head(6)
# Out:
# 0    Marketing
# 1        Sales
# 2           HR
# 3      Finance
# 4           IT
# 5      Support
# Name: department, dtype: object

# %%
df.loc[[100,101,102,103,104,220,222],["employee_name","monthly_sales"]]
# Out:
#           employee_name  monthly_sales
# 100     Margaret Joseph          51730
# 101           Mary Kirk         334417
# 102  Christopher Finley         387571
# 103        Jake Stanley          30679
# 104         Tammy Garza         106200
# 220         Julie Jones         197037
# 222     Cheryl Martinez          69198

# %%
df.iloc[[0,1,2,3,4,5,6],[9,12]]
# Out:
#    department_id   head_of_department
# 0              4     Kenneth Crawford
# 1              5  Katherine Flores MD
# 2              3        Patrick Braun
# 3              5          Aimee Smith
# 4              5          Joshua Love
# 5              2          Jared Meyer
# 6              3                  NaN

# %%
df.head(5)
# Out:
#    employee_id     employee_name region   hire_date  monthly_salary  \
# 0            1  Jermaine Burgess  North  05-06-2016           94618
# 1            2        Sarah Lara  North  23-07-2015          113596
# 2            3     Peter Pearson   West  16-08-2017           54288
# 3            4  Crystal Martinez  South  13-01-2024          119947
# 4            5   Andrea Matthews  South  20-04-2023           75091
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 0         377245                   34                   2                 20
# 1         225054                   38                   4                  5
# 2         258447                   39                   5                 15
# 3         374710                   24                   5                  5
# 4         372136                   29                   3                  5
#
#    department_id department  annual_budget   head_of_department
# ...

# %%
df["head_of_department"].head()
# Out:
# 0       Kenneth Crawford
# 1    Katherine Flores MD
# 2          Patrick Braun
# 3            Aimee Smith
# 4            Joshua Love
# Name: head_of_department, dtype: object

# %%
vari=df.loc[[20,21,23,24,25,26,28,29,30,], ["employee_name","num_clients_handled"]]
sns.barplot(x="employee_name", y="num_clients_handled", data=vari)
plt.show()

# %%
vari=df.iloc[[0,1,2,3,16], [5,7]]
plt.plot(vari["monthly_sales"], vari["performance_rating"])
plt.show()

# %%
df.loc[[3]]
# Out:
#    employee_id     employee_name region   hire_date  monthly_salary  \
# 3            4  Crystal Martinez  South  13-01-2024          119947
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 3         374710                   24                   5                  5
#
#    department_id department  annual_budget head_of_department
# 3              5    Finance      9528253.0        Aimee Smith

# %%
Q. Find employees with a performance_rating of 5.

df[(df["performance_rating"]>=5)]
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 8                9      Susan Edwards  North  25-06-2018           88785
# 10              11  Elizabeth Gilbert  North  16-08-2018           99037
# 19              20    Tyler Patterson  South  14-12-2017          111689
# ...            ...                ...    ...         ...             ...
# 19974        19975      Denise Moreno  North  19-08-2020          107917
# 19979        19980    Mary Villanueva  South  24-01-2024          102039
# 19980        19981         Sean Lopez   East  14-06-2022          109860
# 19985        19986     Rebecca Malone   East  20-02-2023           55381
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
# Q10. Count how many employees are in each region.
df.groupby("region")["employee_id"].count()
# Out:
# region
# East     4967
# North    5056
# South    4905
# West     5072
# Name: employee_id, dtype: int64

# %%
# Q. Find average monthly sales by department.
df.groupby("department")["monthly_sales"].mean()
# Out:
# department
# Finance      374710.0
# HR           258447.0
# IT           372136.0
# Marketing    377245.0
# Sales        225054.0
# Support      276302.0
# Name: monthly_sales, dtype: float64

# %%
# Q. Get summary statistics of monthly_salary.
df["monthly_salary"].describe()
# Out:
# count     20000.000000
# mean      74864.934200
# std       26107.521371
# min       30002.000000
# 25%       52052.750000
# 50%       75115.000000
# 75%       97558.250000
# max      119999.000000
# Name: monthly_salary, dtype: float64

# %%
# Q. Sort employees by region and then monthly_salary (high to low).
df.sort_values(["region", "monthly_salary"], ascending=False)
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 9118          9119   Travis Alexander   West  30-06-2021          119999
# 9033          9034       Terry Atkins   West  04-07-2017          119974
# 13246        13247     Brian Schaefer   West  07-09-2021          119950
# 17224        17225       Shelia Ortiz   West  13-10-2023          119927
# 4637          4638        Brian Klein   West  01-05-2016          119898
# ...            ...                ...    ...         ...             ...
# 19897        19898   Cheryl Dougherty   East  04-07-2020           30107
# 6354          6355  Dr. Jeffery Young   East  15-03-2023           30096
# 14936        14937   Robert Hernandez   East  02-12-2017           30082
# 6494          6495   Benjamin Sweeney   East  22-11-2017           30025
# 17005        17006         Beth Lopez   East  14-09-2019           30013
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
# Q. Check for missing values in each column.
df.isnull().sum()
# Out:
# employee_id                0
# employee_name              0
# region                     0
# hire_date                  0
# monthly_salary             0
# monthly_sales              0
# num_clients_handled        0
# performance_rating         0
# incentive_percent          0
# department_id              0
# department             19994
# annual_budget          19994
# head_of_department     19994
# dtype: int64

# %%
# Q. Find employees in the “Sales” department with monthly sales > ₹300,000.
df[(df["department"]=="Sales") & (df["monthly_sales"]>300000)]
# Out:
# Empty DataFrame
# Columns: [employee_id, employee_name, region, hire_date, monthly_salary, monthly_sales, num_clients_handled, performance_rating, incentive_percent, department_id, department, annual_budget, head_of_department]
# Index: []

# %%
# Create a new column annual_salary from monthly_salary.
df[(df["annual_salary"])==(df["monthly_salary"]*12)].tail(3)
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# 19997         269492                   31                   1
# 19998         138202                    2                   3
# 19999          28284                   45                   4
#
#        incentive_percent  department_id department  annual_budget  \
# 19997                  5              2        NaN            NaN
# 19998                 15              3        NaN            NaN
# 19999                  0              2        NaN            NaN
#
#       head_of_department  annual_salary
# 19997                NaN        1133268
# 19998                NaN         818292
# ...

# %%
# Q. Show the first 5 employees from the “South” region.
df[(df["region"]=="South")].head()
# Out:
#     employee_id     employee_name region   hire_date  monthly_salary  \
# 3             4  Crystal Martinez  South  13-01-2024          119947
# 4             5   Andrea Matthews  South  20-04-2023           75091
# 12           13       Stacey Hunt  South  30-04-2018          112386
# 13           14  Brooke Patterson  South  22-03-2024           65712
# 19           20   Tyler Patterson  South  14-12-2017          111689
#
#     monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 3          374710                   24                   5                  5
# 4          372136                   29                   3                  5
# 12         207732                   36                   4                  0
# 13         199310                   15                   2                  0
# 19         313890                   11                   5                  5
#
#     department_id department  annual_budget head_of_department  annual_salary
# ...

# %%
# Q. Drop any rows where annual_budget is missing.
df["annual_budget"].isnull().sum()
# Out:
# 19994

# %%
df.dropna(subset=["annual_budget"],  inplace=False)
# Out:
#    employee_id      employee_name region   hire_date  monthly_salary  \
# 0            1   Jermaine Burgess  North  05-06-2016           94618
# 1            2         Sarah Lara  North  23-07-2015          113596
# 2            3      Peter Pearson   West  16-08-2017           54288
# 3            4   Crystal Martinez  South  13-01-2024          119947
# 4            5    Andrea Matthews  South  20-04-2023           75091
# 5            6  Michael Nicholson   West  02-11-2015          108872
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 0         377245                   34                   2                 20
# 1         225054                   38                   4                  5
# 2         258447                   39                   5                 15
# 3         374710                   24                   5                  5
# 4         372136                   29                   3                  5
# ...

# %%
# Q. Get the details of the employee at index 10.
df.loc[10]
# Out:
# employee_id                           11
# employee_name          Elizabeth Gilbert
# region                             North
# hire_date                     16-08-2018
# monthly_salary                     99037
# monthly_sales                     386358
# num_clients_handled                   38
# performance_rating                     5
# incentive_percent                     15
# department_id                          4
# department                           NaN
# annual_budget                        NaN
# head_of_department                   NaN
# annual_salary                    1188444
# Name: 10, dtype: object

# %%
# Q. Add a new column sales_per_client = monthly_sales / num_clients_handled.
df["sales_per_client"]=df["monthly_sales"]/df["num_clients_handled"]
df.loc[[0,1,2]]
# Out:
#    employee_id     employee_name region   hire_date  monthly_salary  \
# 0            1  Jermaine Burgess  North  05-06-2016           94618
# 1            2        Sarah Lara  North  23-07-2015          113596
# 2            3     Peter Pearson   West  16-08-2017           54288
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 0         377245                   34                   2                 20
# 1         225054                   38                   4                  5
# 2         258447                   39                   5                 15
#
#    department_id department  annual_budget   head_of_department  \
# 0              4  Marketing      1520961.0     Kenneth Crawford
# 1              5      Sales      3718752.0  Katherine Flores MD
# 2              3         HR      4346682.0        Patrick Braun
#
#    annual_salary  sales_per_client
# 0        1135416      11095.441176
# 1        1363152       5922.473684
# ...

# %%
#Q. Create a new column total_compensation as monthly_salary + 10% of monthly_sales.
df["total_compensation"]=df["monthly_salary"]+df["monthly_sales"]*0.1
df
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 4                5    Andrea Matthews  South  20-04-2023           75091
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
# Q. Find employees with more than 30 clients handled and monthly sales above ₹250,000.
df[(df["num_clients_handled"]>=30) & (df["monthly_sales"]>250000)]
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 2                3      Peter Pearson   West  16-08-2017           54288
# 6                7  Jessica Hernandez   West  05-04-2018           89216
# 7                8        Mary Morrow   West  12-04-2024          107162
# 10              11  Elizabeth Gilbert  North  16-08-2018           99037
# ...            ...                ...    ...         ...             ...
# 19978        19979      William Perez  South  13-09-2018           98391
# 19980        19981         Sean Lopez   East  14-06-2022          109860
# 19986        19987    Valerie Morales  South  28-03-2023          101560
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
# Q. Sort by salary from high to low.
df.sort_values(["monthly_salary"], ascending=False)
# Out:
#        employee_id       employee_name region   hire_date  monthly_salary  \
# 9118          9119    Travis Alexander   West  30-06-2021          119999
# 12177        12178           Anne King  South  22-05-2022          119990
# 15655        15656         Maria Scott  North  14-02-2018          119979
# 9033          9034        Terry Atkins   West  04-07-2017          119974
# 19376        19377      Edward Salazar  North  11-03-2023          119968
# ...            ...                 ...    ...         ...             ...
# 15749        15750     Stephen Webster  South  03-02-2020           30011
# 4161          4162     Melissa Griffin  South  23-09-2022           30010
# 10440        10441         Pamela Hill  South  01-03-2021           30009
# 19197        19198         James Dixon  North  19-02-2022           30005
# 11915        11916  Jennifer Gallagher   West  14-04-2018           30002
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
# Q. Get all columns for employee_id 101.
df.loc[101]
# Out:
# employee_id                      102
# employee_name              Mary Kirk
# region                          West
# hire_date                 10-01-2020
# monthly_salary                 31530
# monthly_sales                 334417
# num_clients_handled                3
# performance_rating                 5
# incentive_percent                 10
# department_id                      1
# department                       NaN
# annual_budget                    NaN
# head_of_department               NaN
# annual_salary                 378360
# sales_per_client       111472.333333
# total_compensation           64971.7
# Name: 101, dtype: object

# %%
# Q. Drop rows where department or annual_budget is missing.
df.dropna(subset=["department", "annual_budget"], inplace=False)
# Out:
#    employee_id      employee_name region   hire_date  monthly_salary  \
# 0            1   Jermaine Burgess  North  05-06-2016           94618
# 1            2         Sarah Lara  North  23-07-2015          113596
# 2            3      Peter Pearson   West  16-08-2017           54288
# 3            4   Crystal Martinez  South  13-01-2024          119947
# 4            5    Andrea Matthews  South  20-04-2023           75091
# 5            6  Michael Nicholson   West  02-11-2015          108872
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 0         377245                   34                   2                 20
# 1         225054                   38                   4                  5
# 2         258447                   39                   5                 15
# 3         374710                   24                   5                  5
# 4         372136                   29                   3                  5
# ...

# %%
# Q. Count how many employees work in each department.
df.groupby("department")["employee_id"].count()
# Out:
# department
# Finance      1
# HR           1
# IT           1
# Marketing    1
# Sales        1
# Support      1
# Name: employee_id, dtype: int64

# %%
# Q. Find average salary and sales per department.
df.groupby("department")[["monthly_salary","monthly_sales"]].mean()
# Out:
#             monthly_salary  monthly_sales
# department
# Finance           119947.0       374710.0
# HR                 54288.0       258447.0
# IT                 75091.0       372136.0
# Marketing          94618.0       377245.0
# Sales             113596.0       225054.0
# Support           108872.0       276302.0

# %%
# Q. Sort employees by department and then monthly_sales.
df.sort_values(["department", "monthly_sales"], ascending=False)
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 5                6  Michael Nicholson   West  02-11-2015          108872
# 1                2         Sarah Lara  North  23-07-2015          113596
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 4                5    Andrea Matthews  South  20-04-2023           75091
# 2                3      Peter Pearson   West  16-08-2017           54288
# ...            ...                ...    ...         ...             ...
# 2101          2102    Matthew Bradley  North  25-07-2017          107981
# 10738        10739         James Diaz   East  24-11-2017           92058
# 11044        11045    Kimberly Thomas  South  17-01-2020           35166
# 19277        19278   Jennifer Johnson   West  09-10-2019           81691
# 6451          6452    Katherine Lopez   East  22-04-2024          107449
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
# Q. Show employees hired in or after 2022.
df[df['hire_date'] >= "2022-01-01"]
# Out:
#        employee_id         employee_name region   hire_date  monthly_salary  \
# 1                2            Sarah Lara  North  23-07-2015          113596
# 8                9         Susan Edwards  North  25-06-2018           88785
# 12              13           Stacey Hunt  South  30-04-2018          112386
# 13              14      Brooke Patterson  South  22-03-2024           65712
# 17              18        Sydney Ramirez   East  26-05-2018           90159
# ...            ...                   ...    ...         ...             ...
# 19988        19989           Robert Shea  South  24-10-2017           48291
# 19990        19991         Megan Jackson   West  30-08-2017           63904
# 19993        19994  Christopher Williams   East  21-10-2015           37245
# 19994        19995         Melissa White  South  30-03-2020          117579
# 19996        19997           Ellen Grant  North  28-09-2021           93532
#
# ...

# %%
# Q. Create a new column high_performer = True if performance_rating is 4 or 5.
df["high_performer"]=(df["performance_rating"]==4) | (df["performance_rating"]==5
df
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 0                1   Jermaine Burgess  North  05-06-2016           94618
# 1                2         Sarah Lara  North  23-07-2015          113596
# 2                3      Peter Pearson   West  16-08-2017           54288
# 3                4   Crystal Martinez  South  13-01-2024          119947
# 4                5    Andrea Matthews  South  20-04-2023           75091
# ...            ...                ...    ...         ...             ...
# 19995        19996      Jeffrey Reyes  North  09-04-2020          110831
# 19996        19997        Ellen Grant  North  28-09-2021           93532
# 19997        19998   Shane Hughes DVM   West  02-06-2017           94439
# 19998        19999     Lindsay Landry  North  12-10-2019           68191
# 19999        20000  Mrs. Debra Oliver   East  17-09-2023           96951
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
# Q. Show employees in either "IT" or "HR" department with salary above ₹60,000.
df[(df["department"]=="IT")| (df["department"]=="HR") & (df["monthly_salary"]>60000)]
# Out:
#    employee_id    employee_name region   hire_date  monthly_salary  \
# 4            5  Andrea Matthews  South  20-04-2023           75091
#
#    monthly_sales  num_clients_handled  performance_rating  incentive_percent  \
# 4         372136                   29                   3                  5
#
#    department_id department  annual_budget head_of_department  annual_salary  \
# 4              5         IT      5762252.0        Joshua Love         901092
#
#    sales_per_client  total_compensation  high_performer
# 4      12832.275862            112304.6           False

# %%
# Q. Sort by hire date (newest first), then by performance_rating.
df.sort_values(["hire_date", "performance_rating"], ascending=True)
# Out:
#        employee_id      employee_name region   hire_date  monthly_salary  \
# 14208        14209  Marcus Lawson DVM   West  01-01-2016          113150
# 14968        14969       Amanda Doyle   West  01-01-2016           35730
# 445            446       Robert Leach  South  01-01-2016           82652
# 4218          4219    Alex Villarreal   West  01-01-2016          108567
# 13980        13981         Eric Smith   West  01-01-2016          111410
# ...            ...                ...    ...         ...             ...
# 4850          4851       Holly Medina   East  31-12-2022           92419
# 15138        15139       John Perkins  North  31-12-2022           74497
# 1046          1047       James Howard  North  31-12-2023           72255
# 6038          6039         Cody Rivas  South  31-12-2023           99975
# 14503        14504   Christopher Hall   East  31-12-2023           78744
#
#        monthly_sales  num_clients_handled  performance_rating  \
# ...

# %%
# Q. How many employees are from each region?
df["region"].value_counts()
# Out:
# region
# West     5072
# North    5056
# East     4967
# South    4905
# Name: count, dtype: int64

# %%
# Q. How many employees are from each region?
df["region"].value_counts()
sns.countplot(x="region", data=df)
plt.show()

# %%
# Q. How many employees belong to each performance rating?
df["performance_rating"].value_counts()
# Out:
# performance_rating
# 1    4081
# 5    4069
# 2    4007
# 3    3958
# 4    3885
# Name: count, dtype: int64

# %%
# Q. How many employees belong to each performance rating?
df.groupby("performance_rating")["employee_id"].count()
# Out:
# performance_rating
# 1    4081
# 2    4007
# 3    3958
# 4    3885
# 5    4069
# Name: employee_id, dtype: int64

# %%
df.groupby("region")["employee_id"].count()
# Out:
# region
# East     4967
# North    5056
# South    4905
# West     5072
# Name: employee_id, dtype: int64
